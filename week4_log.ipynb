# %% [markdown]
# '''''''''''''''''''''''''''''''''''Download and read logs.txt attcahed with this assignment.
# \[]
#
# Extract:
#
# Timestamp
#
# Error message
#
# Count number of errors
#
# Write summary to report.txt
#
# Follow PEP8
#
# Use docstrings

# %%
#read log.txt
filename = "logs.txt"
with open(filename,"r") as file:
    lines=file.readlines()
    for i, line in enumerate(lines,1):
        print(line.strip())
# Out:
# 2026-01-10 08:15:23 INFO User login successful for user_id=1021
# 2026-01-10 08:16:01 INFO Data sync started
# 2026-01-10 08:16:05 ERROR Failed to connect to database
# 2026-01-10 08:16:07 INFO Retrying database connection
# 2026-01-10 08:16:12 ERROR Database connection timeout
# 2026-01-10 08:17:45 WARNING High memory usage detected
# 2026-01-10 08:18:02 INFO Scheduled job started
# 2026-01-10 08:18:09 ERROR File not found: config.yaml
# 2026-01-10 08:18:15 INFO Scheduled job completed
# 2026-01-10 08:19:30 INFO User logout successful for user_id=1021
# 2026-01-10 08:20:10 ERROR Permission denied while writing to disk
# 2026-01-10 08:21:00 INFO System health check passed

# %%
   #couldn't print only the timestamp
filename = "logs.txt"
with open(filename,"r") as file:
    lines=file.readlines()
    for line in lines:
        if "2026" in line:
            print(line.strip())
               #couldn't print only the timestamp
# Out:
# 2026-01-10 08:15:23 INFO User login successful for user_id=1021
# 2026-01-10 08:16:01 INFO Data sync started
# 2026-01-10 08:16:05 ERROR Failed to connect to database
# 2026-01-10 08:16:07 INFO Retrying database connection
# 2026-01-10 08:16:12 ERROR Database connection timeout
# 2026-01-10 08:17:45 WARNING High memory usage detected
# 2026-01-10 08:18:02 INFO Scheduled job started
# 2026-01-10 08:18:09 ERROR File not found: config.yaml
# 2026-01-10 08:18:15 INFO Scheduled job completed
# 2026-01-10 08:19:30 INFO User logout successful for user_id=1021
# 2026-01-10 08:20:10 ERROR Permission denied while writing to disk
# 2026-01-10 08:21:00 INFO System health check passed

# %%
# error message
filename = "logs.txt"
with open(filename,"r") as file:
    lines=file.readlines()
    for line in lines:
        if "ERROR" in line:
            print(line.strip())
# Out:
# 2026-01-10 08:16:05 ERROR Failed to connect to database
# 2026-01-10 08:16:12 ERROR Database connection timeout
# 2026-01-10 08:18:09 ERROR File not found: config.yaml
# 2026-01-10 08:20:10 ERROR Permission denied while writing to disk

# %%
#error count
filename = "logs.txt"

error_count=0
with open(filename,"r") as file:
    lines=file.readlines()
    for line in lines:
        if "ERROR" in line:
            error_count=error_count+1
           

print(error_count)
# Out:
# 4

# %%
filename = 'report'

with open(filename,'w') as file:
    file.write("The log.txt attached with the assignment has been downloaded and read.\n'")
    file.write("Unable to extract timestamp only.\n'")
    file.write("successfully extracted error message.\n'")
    file.write("number of errors was 4.n'")

print(f'sucessfully wrote summary to"{filename}"')
# Out:
# sucessfully wrote summary to"report"
